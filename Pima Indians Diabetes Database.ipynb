# %% [markdown]
# # TensorFlow Classification

# %% [markdown]
# ## Data
#
# https://archive.ics.uci.edu/ml/datasets/pima+indians+diabetes
#
# 1. Title: Pima Indians Diabetes Database
#
# 2. Sources:
#    (a) Original owners: National Institute of Diabetes and Digestive and
#                         Kidney Diseases
#    (b) Donor of database: Vincent Sigillito (vgs@aplcen.apl.jhu.edu)
#                           Research Center, RMI Group Leader
#                           Applied Physics Laboratory
#                           The Johns Hopkins University
#                           Johns Hopkins Road
#                           Laurel, MD 20707
#                           (301) 953-6231
#    (c) Date received: 9 May 1990
#
# 3. Past Usage:
#     1. Smith,~J.~W., Everhart,~J.~E., Dickson,~W.~C., Knowler,~W.~C., \&
#        Johannes,~R.~S. (1988). Using the ADAP learning algorithm to forecast
#        the onset of diabetes mellitus.  In {\it Proceedings of the Symposium
#        on Computer Applications and Medical Care} (pp. 261--265).  IEEE
#        Computer Society Press.
#
#        The diagnostic, binary-valued variable investigated is whether the
#        patient shows signs of diabetes according to World Health Organization
#        criteria (i.e., if the 2 hour post-load plasma glucose was at least
#        200 mg/dl at any survey  examination or if found during routine medical
#        care).   The population lives near Phoenix, Arizona, USA.
#
#        Results: Their ADAP algorithm makes a real-valued prediction between
#        0 and 1.  This was transformed into a binary decision using a cutoff of
#        0.448.  Using 576 training instances, the sensitivity and specificity
#        of their algorithm was 76% on the remaining 192 instances.
#
# 4. Relevant Information:
#       Several constraints were placed on the selection of these instances from
#       a larger database.  In particular, all patients here are females at
#       least 21 years old of Pima Indian heritage.  ADAP is an adaptive learning
#       routine that generates and executes digital analogs of perceptron-like
#       devices.  It is a unique algorithm; see the paper for details.
#
# 5. Number of Instances: 768
#
# 6. Number of Attributes: 8 plus class
#
#     7. For Each Attribute: (all numeric-valued)
#        1. Number of times pregnant
#        2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#        3. Diastolic blood pressure (mm Hg)
#        4. Triceps skin fold thickness (mm)
#        5. 2-Hour serum insulin (mu U/ml)
#        6. Body mass index (weight in kg/(height in m)^2)
#        7. Diabetes pedigree function
#        8. Age (years)
#        9. Class variable (0 or 1)
#
# 8. Missing Attribute Values: Yes
#
# 9. Class Distribution: (class value 1 is interpreted as "tested positive for
#    diabetes")
#
#    Class Value  Number of instances
#    0            500
#    1            268
#
# 10. Brief statistical analysis:
#
#         Attribute number:    Mean:   Standard Deviation:
#         1.                     3.8     3.4
#         2.                   120.9    32.0
#         3.                    69.1    19.4
#         4.                    20.5    16.0
#         5.                    79.8   115.2
#         6.                    32.0     7.9
#         7.                     0.5     0.3
#         8.                    33.2    11.8

# %%
import pandas as pd

# %%
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %% [markdown]
# ### Clean the Data

# %%
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %% [markdown]
# ### Feature Columns

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
# Number_pregnant          768 non-null float64
# Glucose_concentration    768 non-null float64
# Blood_pressure           768 non-null float64
# Triceps                  768 non-null float64
# Insulin                  768 non-null float64
# BMI                      768 non-null float64
# Pedigree                 768 non-null float64
# Age                      768 non-null int64
# Class                    768 non-null int64
# Group                    768 non-null object
# dtypes: float64(7), int64(2), object(1)
# memory usage: 60.1+ KB

# %%
import tensorflow as tf
# Out:
# C:\Users\caiyi\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\caiyi\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\caiyi\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\caiyi\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\caiyi\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\caiyi\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ### Continuous Features
#
# * Number of times pregnant
# * Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * Diastolic blood pressure (mm Hg)
# * Triceps skin fold thickness (mm)
# * 2-Hour serum insulin (mu U/ml)
# * Body mass index (weight in kg/(height in m)^2)
# * Diabetes pedigree function

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %% [markdown]
# ### Categorical Features

# %% [markdown]
# If you know the set of all possible feature values of a column and there are only a few of them, you can use categorical_column_with_vocabulary_list. If you don't know the set of possible values in advance you can use categorical_column_with_hash_bucket

# %%
#assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])
# Alternative
 assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', vocabulary_list=('A', 'B', 'C', 'D'), hash_bucket_size=10)

# %% [markdown]
# ### Converting Continuous to Categorical

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)

# %%
age_buckets = tf.feature_column.bucketized_column(age, boundaries=[20,30,40,50,60,70,80])

# %% [markdown]
# ### Putting them together

# %%
age_buckets
# Out:
# BucketizedColumn(source_column=NumericColumn(key='Age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(20, 30, 40, 50, 60, 70, 80))

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,assigned_group, age_buckets]

# %% [markdown]
# ### Train Test Split

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
# Number_pregnant          768 non-null float64
# Glucose_concentration    768 non-null float64
# Blood_pressure           768 non-null float64
# Triceps                  768 non-null float64
# Insulin                  768 non-null float64
# BMI                      768 non-null float64
# Pedigree                 768 non-null float64
# Age                      768 non-null int64
# Class                    768 non-null int64
# Group                    768 non-null object
# dtypes: float64(7), int64(2), object(1)
# memory usage: 60.1+ KB

# %%
x_data = diabetes.drop('Class',axis=1)

# %%
labels = diabetes['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,labels,test_size=0.33, random_state=101)

# %% [markdown]
# ### Input Function

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %% [markdown]
# ### Creating the Model

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols,n_classes=2)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0221 18:22:21.120839 15956 estimator.py:1811] Using temporary folder as model directory: C:\Users\caiyi\AppData\Local\Temp\tmpaq_jeivq

# %%
model.train(input_fn=input_func,steps=1000)
# Out:
# W0221 18:22:21.611235 15956 deprecation.py:323] From C:\Users\caiyi\Anaconda3\lib\site-packages\tensorflow\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# W0221 18:22:21.630147 15956 deprecation.py:323] From C:\Users\caiyi\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W0221 18:22:21.632141 15956 deprecation.py:323] From C:\Users\caiyi\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W0221 18:22:21.948010 15956 deprecation.py:323] From C:\Users\caiyi\Anaconda3\lib\site-packages\tensorflow\python\ops\sparse_ops.py:1719: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0221 18:22:22.093620 15956 deprecation.py:323] From C:\Users\caiyi\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\canned\linear.py:308: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0221 18:22:23.018909 15956 deprecation.py:323] From C:\Users\caiyi\Anaconda3\lib\site-packages\tensorflow\python\training\monitored_session.py:875: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.

# %%
# Useful link ofr your own data
# https://stackoverflow.com/questions/44664285/what-are-the-contraints-for-tensorflow-scope-names

# %% [markdown]
# ## Evaluation

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# W0221 18:22:26.471930 15956 deprecation.py:323] From C:\Users\caiyi\Anaconda3\lib\site-packages\tensorflow\python\ops\metrics_impl.py:2027: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W0221 18:22:26.735851 15956 metrics_impl.py:804] Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# W0221 18:22:26.764439 15956 metrics_impl.py:804] Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# W0221 18:22:26.912078 15956 deprecation.py:323] From C:\Users\caiyi\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.

# %%
results
# Out:
# {'accuracy': 0.72440946,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.7809553,
#  'auc_precision_recall': 0.61747324,
#  'average_loss': 0.5372547,
#  'label/mean': 0.34251967,
#  'loss': 5.248565,
#  'precision': 0.60240966,
#  'prediction/mean': 0.37253925,
#  'recall': 0.57471263,
#  'global_step': 1000}

# %% [markdown]
# ## Predictions

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
# Predictions is a generator! 
predictions = model.predict(pred_input_func)

# %%
list(predictions)
# Out:
# [{'logits': array([0.15726423], dtype=float32),
#   'logistic': array([0.53923523], dtype=float32),
#   'probabilities': array([0.46076477, 0.53923523], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.51784766], dtype=float32),
#   'logistic': array([0.6266443], dtype=float32),
#   'probabilities': array([0.37335566, 0.6266443 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.39665598], dtype=float32),
#   'logistic': array([0.40211606], dtype=float32),
#   'probabilities': array([0.59788394, 0.40211603], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.76112527], dtype=float32),
#   'logistic': array([0.31840202], dtype=float32),
#   'probabilities': array([0.681598  , 0.31840202], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7672302], dtype=float32),
#   'logistic': array([0.14588714], dtype=float32),
#   'probabilities': array([0.85411286, 0.14588712], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.7065952], dtype=float32),
#   'logistic': array([0.66964835], dtype=float32),
#   'probabilities': array([0.33035162, 0.6696484 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.36111212], dtype=float32),
#   'logistic': array([0.58930963], dtype=float32),
#   'probabilities': array([0.41069037, 0.58930963], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5826991], dtype=float32),
#   'logistic': array([0.35831177], dtype=float32),
#   'probabilities': array([0.6416882 , 0.35831177], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1912245], dtype=float32),
#   'logistic': array([0.23304], dtype=float32),
#   'probabilities': array([0.76695997, 0.23304   ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0579283], dtype=float32),
#   'logistic': array([0.25770554], dtype=float32),
#   'probabilities': array([0.74229443, 0.25770554], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9541304], dtype=float32),
#   'logistic': array([0.1241037], dtype=float32),
#   'probabilities': array([0.87589633, 0.12410368], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.707192], dtype=float32),
#   'logistic': array([0.15352827], dtype=float32),
#   'probabilities': array([0.84647167, 0.15352827], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7413266], dtype=float32),
#   'logistic': array([0.32271415], dtype=float32),
#   'probabilities': array([0.67728585, 0.32271412], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.3364476], dtype=float32),
#   'logistic': array([0.58332735], dtype=float32),
#   'probabilities': array([0.41667265, 0.58332735], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6164155], dtype=float32),
#   'logistic': array([0.16569984], dtype=float32),
#   'probabilities': array([0.83430016, 0.1656998 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7449486], dtype=float32),
#   'logistic': array([0.321923], dtype=float32),
#   'probabilities': array([0.67807704, 0.32192296], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.52415943], dtype=float32),
#   'logistic': array([0.37188017], dtype=float32),
#   'probabilities': array([0.6281199 , 0.37188014], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9329193], dtype=float32),
#   'logistic': array([0.1264278], dtype=float32),
#   'probabilities': array([0.8735722, 0.1264278], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.4553913], dtype=float32),
#   'logistic': array([0.3880797], dtype=float32),
#   'probabilities': array([0.6119203, 0.3880797], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8332374], dtype=float32),
#   'logistic': array([0.13785306], dtype=float32),
#   'probabilities': array([0.862147  , 0.13785306], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3290915], dtype=float32),
#   'logistic': array([0.20930973], dtype=float32),
#   'probabilities': array([0.79069036, 0.20930968], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.88343024], dtype=float32),
#   'logistic': array([0.29246747], dtype=float32),
#   'probabilities': array([0.7075326 , 0.29246747], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.6722244], dtype=float32),
#   'logistic': array([0.6620011], dtype=float32),
#   'probabilities': array([0.33799896, 0.6620011 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2978725], dtype=float32),
#   'logistic': array([0.21452329], dtype=float32),
#   'probabilities': array([0.78547674, 0.21452329], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.530038], dtype=float32),
#   'logistic': array([0.17798814], dtype=float32),
#   'probabilities': array([0.8220119 , 0.17798813], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.2727273], dtype=float32),
#   'logistic': array([0.78120923], dtype=float32),
#   'probabilities': array([0.21879075, 0.7812093 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5190674], dtype=float32),
#   'logistic': array([0.1795989], dtype=float32),
#   'probabilities': array([0.82040113, 0.1795989 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.87504923], dtype=float32),
#   'logistic': array([0.29420477], dtype=float32),
#   'probabilities': array([0.7057952 , 0.29420474], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.2081876], dtype=float32),
#   'logistic': array([0.09901765], dtype=float32),
#   'probabilities': array([0.9009824 , 0.09901765], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.36674345], dtype=float32),
#   'logistic': array([0.59067184], dtype=float32),
#   'probabilities': array([0.40932813, 0.59067184], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.8645437], dtype=float32),
#   'logistic': array([0.94606566], dtype=float32),
#   'probabilities': array([0.05393439, 0.94606566], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.29484028], dtype=float32),
#   'logistic': array([0.42681932], dtype=float32),
#   'probabilities': array([0.57318074, 0.42681932], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8178569], dtype=float32),
#   'logistic': array([0.30621877], dtype=float32),
#   'probabilities': array([0.6937812 , 0.30621877], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.35123348], dtype=float32),
#   'logistic': array([0.5869167], dtype=float32),
#   'probabilities': array([0.41308334, 0.5869167 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1229572], dtype=float32),
#   'logistic': array([0.24546319], dtype=float32),
#   'probabilities': array([0.75453687, 0.24546318], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.42179537], dtype=float32),
#   'logistic': array([0.39608723], dtype=float32),
#   'probabilities': array([0.6039128, 0.3960872], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.08668971], dtype=float32),
#   'logistic': array([0.52165884], dtype=float32),
#   'probabilities': array([0.47834116, 0.5216589 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.6185453], dtype=float32),
#   'logistic': array([0.6498876], dtype=float32),
#   'probabilities': array([0.35011238, 0.6498876 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.096549], dtype=float32),
#   'logistic': array([0.7496129], dtype=float32),
#   'probabilities': array([0.25038707, 0.7496129 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6362064], dtype=float32),
#   'logistic': array([0.34610462], dtype=float32),
#   'probabilities': array([0.6538954, 0.3461046], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5217742], dtype=float32),
#   'logistic': array([0.17920041], dtype=float32),
#   'probabilities': array([0.8207996 , 0.17920041], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.21122849], dtype=float32),
#   'logistic': array([0.55261165], dtype=float32),
#   'probabilities': array([0.44738832, 0.55261165], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7267363], dtype=float32),
#   'logistic': array([0.15100548], dtype=float32),
#   'probabilities': array([0.8489945 , 0.15100552], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.15531766], dtype=float32),
#   'logistic': array([0.53875154], dtype=float32),
#   'probabilities': array([0.46124846, 0.53875154], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.802428], dtype=float32),
#   'logistic': array([0.14155573], dtype=float32),
#   'probabilities': array([0.8584442 , 0.14155577], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1436791], dtype=float32),
#   'logistic': array([0.10492337], dtype=float32),
#   'probabilities': array([0.89507663, 0.10492336], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5187355], dtype=float32),
#   'logistic': array([0.62685204], dtype=float32),
#   'probabilities': array([0.37314796, 0.62685204], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4619803], dtype=float32),
#   'logistic': array([0.18816462], dtype=float32),
#   'probabilities': array([0.81183535, 0.18816462], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3509359], dtype=float32),
#   'logistic': array([0.20571741], dtype=float32),
#   'probabilities': array([0.7942826, 0.2057174], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0845575], dtype=float32),
#   'logistic': array([0.11060683], dtype=float32),
#   'probabilities': array([0.8893932 , 0.11060683], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6247373], dtype=float32),
#   'logistic': array([0.1645526], dtype=float32),
#   'probabilities': array([0.83544743, 0.16455258], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1466979], dtype=float32),
#   'logistic': array([0.24109274], dtype=float32),
#   'probabilities': array([0.75890726, 0.24109274], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1053078], dtype=float32),
#   'logistic': array([0.2487467], dtype=float32),
#   'probabilities': array([0.7512533 , 0.24874668], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.45122904], dtype=float32),
#   'logistic': array([0.3890686], dtype=float32),
#   'probabilities': array([0.6109314, 0.3890686], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.868924], dtype=float32),
#   'logistic': array([0.13366625], dtype=float32),
#   'probabilities': array([0.8663337 , 0.13366628], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2998834], dtype=float32),
#   'logistic': array([0.21418461], dtype=float32),
#   'probabilities': array([0.78581536, 0.21418464], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3441366], dtype=float32),
#   'logistic': array([0.20683065], dtype=float32),
#   'probabilities': array([0.7931694, 0.2068306], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.353471], dtype=float32),
#   'logistic': array([0.20530349], dtype=float32),
#   'probabilities': array([0.7946965 , 0.20530349], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.03857613], dtype=float32),
#   'logistic': array([0.50964284], dtype=float32),
#   'probabilities': array([0.49035716, 0.50964284], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6473968], dtype=float32),
#   'logistic': array([0.16146109], dtype=float32),
#   'probabilities': array([0.8385389 , 0.16146109], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1946169], dtype=float32),
#   'logistic': array([0.23243424], dtype=float32),
#   'probabilities': array([0.7675658 , 0.23243423], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.62769294], dtype=float32),
#   'logistic': array([0.65196615], dtype=float32),
#   'probabilities': array([0.34803385, 0.65196615], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5374471], dtype=float32),
#   'logistic': array([0.6312183], dtype=float32),
#   'probabilities': array([0.3687817, 0.6312184], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.05862451], dtype=float32),
#   'logistic': array([0.51465195], dtype=float32),
#   'probabilities': array([0.48534805, 0.5146519 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.644751], dtype=float32),
#   'logistic': array([0.34417337], dtype=float32),
#   'probabilities': array([0.6558267, 0.3441734], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.00366294], dtype=float32),
#   'logistic': array([0.5009157], dtype=float32),
#   'probabilities': array([0.4990843 , 0.50091577], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5921035], dtype=float32),
#   'logistic': array([0.16908816], dtype=float32),
#   'probabilities': array([0.8309118 , 0.16908816], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3931974], dtype=float32),
#   'logistic': array([0.19889781], dtype=float32),
#   'probabilities': array([0.8011022 , 0.19889781], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7072072], dtype=float32),
#   'logistic': array([0.1535263], dtype=float32),
#   'probabilities': array([0.84647375, 0.1535263 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8929334], dtype=float32),
#   'logistic': array([0.13091037], dtype=float32),
#   'probabilities': array([0.86908966, 0.13091038], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.41663492], dtype=float32),
#   'logistic': array([0.6026777], dtype=float32),
#   'probabilities': array([0.39732227, 0.6026777 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1857679], dtype=float32),
#   'logistic': array([0.23401672], dtype=float32),
#   'probabilities': array([0.7659833, 0.2340167], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.22053885], dtype=float32),
#   'logistic': array([0.44508767], dtype=float32),
#   'probabilities': array([0.5549123 , 0.44508767], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.37555444], dtype=float32),
#   'logistic': array([0.59280044], dtype=float32),
#   'probabilities': array([0.4071996, 0.5928005], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.92912656], dtype=float32),
#   'logistic': array([0.28310195], dtype=float32),
#   'probabilities': array([0.7168981 , 0.28310195], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.6428883], dtype=float32),
#   'logistic': array([0.65540606], dtype=float32),
#   'probabilities': array([0.3445939 , 0.65540606], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9221821], dtype=float32),
#   'logistic': array([0.12761843], dtype=float32),
#   'probabilities': array([0.8723815 , 0.12761843], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.434891], dtype=float32),
#   'logistic': array([0.607041], dtype=float32),
#   'probabilities': array([0.392959  , 0.60704094], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.002129], dtype=float32),
#   'logistic': array([0.11897957], dtype=float32),
#   'probabilities': array([0.8810204 , 0.11897957], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.24374974], dtype=float32),
#   'logistic': array([0.5606375], dtype=float32),
#   'probabilities': array([0.43936247, 0.5606375 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.69938153], dtype=float32),
#   'logistic': array([0.33194935], dtype=float32),
#   'probabilities': array([0.66805065, 0.33194935], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6079489], dtype=float32),
#   'logistic': array([0.16687357], dtype=float32),
#   'probabilities': array([0.83312637, 0.16687356], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.23266327], dtype=float32),
#   'logistic': array([0.55790484], dtype=float32),
#   'probabilities': array([0.44209516, 0.55790484], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.43224573], dtype=float32),
#   'logistic': array([0.6064098], dtype=float32),
#   'probabilities': array([0.3935902, 0.6064098], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.27085555], dtype=float32),
#   'logistic': array([0.56730294], dtype=float32),
#   'probabilities': array([0.4326971 , 0.56730294], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6209459], dtype=float32),
#   'logistic': array([0.16507447], dtype=float32),
#   'probabilities': array([0.83492553, 0.16507445], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5517132], dtype=float32),
#   'logistic': array([0.365467], dtype=float32),
#   'probabilities': array([0.634533, 0.365467], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7574401], dtype=float32),
#   'logistic': array([0.1471112], dtype=float32),
#   'probabilities': array([0.85288876, 0.14711124], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.9310132], dtype=float32),
#   'logistic': array([0.71728086], dtype=float32),
#   'probabilities': array([0.28271922, 0.71728086], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.5588391], dtype=float32),
#   'logistic': array([0.82618666], dtype=float32),
#   'probabilities': array([0.17381328, 0.82618666], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.51041377], dtype=float32),
#   'logistic': array([0.62490344], dtype=float32),
#   'probabilities': array([0.37509653, 0.6249035 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3162279], dtype=float32),
#   'logistic': array([0.21144655], dtype=float32),
#   'probabilities': array([0.7885535 , 0.21144655], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.21813744], dtype=float32),
#   'logistic': array([0.44568086], dtype=float32),
#   'probabilities': array([0.55431914, 0.44568086], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.4295168], dtype=float32),
#   'logistic': array([0.39424175], dtype=float32),
#   'probabilities': array([0.6057583 , 0.39424172], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.09586757], dtype=float32),
#   'logistic': array([0.47605145], dtype=float32),
#   'probabilities': array([0.52394855, 0.47605145], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6288695], dtype=float32),
#   'logistic': array([0.34776694], dtype=float32),
#   'probabilities': array([0.65223306, 0.3477669 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.17934364], dtype=float32),
#   'logistic': array([0.45528388], dtype=float32),
#   'probabilities': array([0.5447161 , 0.45528388], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6681424], dtype=float32),
#   'logistic': array([0.15867198], dtype=float32),
#   'probabilities': array([0.84132797, 0.15867199], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.24242532], dtype=float32),
#   'logistic': array([0.56031126], dtype=float32),
#   'probabilities': array([0.43968874, 0.56031126], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.26592052], dtype=float32),
#   'logistic': array([0.5660911], dtype=float32),
#   'probabilities': array([0.43390888, 0.5660911 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1757886], dtype=float32),
#   'logistic': array([0.23581028], dtype=float32),
#   'probabilities': array([0.7641898 , 0.23581028], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5195247], dtype=float32),
#   'logistic': array([0.17953148], dtype=float32),
#   'probabilities': array([0.82046854, 0.17953153], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5829085], dtype=float32),
#   'logistic': array([0.17038396], dtype=float32),
#   'probabilities': array([0.82961607, 0.17038397], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.976745], dtype=float32),
#   'logistic': array([0.2735381], dtype=float32),
#   'probabilities': array([0.7264619 , 0.27353814], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.40201336], dtype=float32),
#   'logistic': array([0.40082872], dtype=float32),
#   'probabilities': array([0.5991713, 0.4008287], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8454192], dtype=float32),
#   'logistic': array([0.13641164], dtype=float32),
#   'probabilities': array([0.86358833, 0.13641164], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6479433], dtype=float32),
#   'logistic': array([0.34345317], dtype=float32),
#   'probabilities': array([0.65654683, 0.34345317], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1832814], dtype=float32),
#   'logistic': array([0.23446271], dtype=float32),
#   'probabilities': array([0.7655373 , 0.23446271], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.2518578], dtype=float32),
#   'logistic': array([0.09518934], dtype=float32),
#   'probabilities': array([0.90481067, 0.09518934], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.014674], dtype=float32),
#   'logistic': array([0.11767085], dtype=float32),
#   'probabilities': array([0.88232917, 0.11767083], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1395233], dtype=float32),
#   'logistic': array([0.7575921], dtype=float32),
#   'probabilities': array([0.2424079, 0.7575921], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5477533], dtype=float32),
#   'logistic': array([0.17541099], dtype=float32),
#   'probabilities': array([0.82458895, 0.17541099], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.866334], dtype=float32),
#   'logistic': array([0.13396648], dtype=float32),
#   'probabilities': array([0.8660335 , 0.13396649], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8506014], dtype=float32),
#   'logistic': array([0.13580227], dtype=float32),
#   'probabilities': array([0.8641977 , 0.13580228], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.02599442], dtype=float32),
#   'logistic': array([0.5064982], dtype=float32),
#   'probabilities': array([0.49350178, 0.5064983 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.07830834], dtype=float32),
#   'logistic': array([0.48043293], dtype=float32),
#   'probabilities': array([0.5195671, 0.4804329], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1947796], dtype=float32),
#   'logistic': array([0.23240519], dtype=float32),
#   'probabilities': array([0.7675948, 0.2324052], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.19769168], dtype=float32),
#   'logistic': array([0.45073742], dtype=float32),
#   'probabilities': array([0.5492626, 0.4507374], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5059133], dtype=float32),
#   'logistic': array([0.18154524], dtype=float32),
#   'probabilities': array([0.81845474, 0.18154524], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2584342], dtype=float32),
#   'logistic': array([0.22124356], dtype=float32),
#   'probabilities': array([0.77875644, 0.22124356], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.02164257], dtype=float32),
#   'logistic': array([0.49458957], dtype=float32),
#   'probabilities': array([0.50541043, 0.49458957], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.01488364], dtype=float32),
#   'logistic': array([0.5037208], dtype=float32),
#   'probabilities': array([0.49627915, 0.5037208 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8084267], dtype=float32),
#   'logistic': array([0.1408284], dtype=float32),
#   'probabilities': array([0.8591716 , 0.14082839], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.36436713], dtype=float32),
#   'logistic': array([0.40990284], dtype=float32),
#   'probabilities': array([0.5900972, 0.4099028], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.8269664], dtype=float32),
#   'logistic': array([0.6957131], dtype=float32),
#   'probabilities': array([0.30428687, 0.6957131 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.24040914], dtype=float32),
#   'logistic': array([0.55981445], dtype=float32),
#   'probabilities': array([0.44018552, 0.55981445], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.32825756], dtype=float32),
#   'logistic': array([0.41866463], dtype=float32),
#   'probabilities': array([0.58133537, 0.41866466], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.29419434], dtype=float32),
#   'logistic': array([0.57302266], dtype=float32),
#   'probabilities': array([0.42697734, 0.57302266], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1972809], dtype=float32),
#   'logistic': array([0.23195928], dtype=float32),
#   'probabilities': array([0.7680407, 0.2319593], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.428138], dtype=float32),
#   'logistic': array([0.19338897], dtype=float32),
#   'probabilities': array([0.80661106, 0.19338898], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8754139], dtype=float32),
#   'logistic': array([0.13291654], dtype=float32),
#   'probabilities': array([0.8670835 , 0.13291654], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0982518], dtype=float32),
#   'logistic': array([0.2500676], dtype=float32),
#   'probabilities': array([0.7499324, 0.2500676], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.0634051], dtype=float32),
#   'logistic': array([0.48415405], dtype=float32),
#   'probabilities': array([0.515846  , 0.48415408], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.7957716], dtype=float32),
#   'logistic': array([0.6890692], dtype=float32),
#   'probabilities': array([0.31093076, 0.6890693 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2916718], dtype=float32),
#   'logistic': array([0.21556997], dtype=float32),
#   'probabilities': array([0.78442997, 0.21556996], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7096937], dtype=float32),
#   'logistic': array([0.15320343], dtype=float32),
#   'probabilities': array([0.8467966 , 0.15320344], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.27536112], dtype=float32),
#   'logistic': array([0.43159145], dtype=float32),
#   'probabilities': array([0.5684086 , 0.43159142], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2327058], dtype=float32),
#   'logistic': array([0.22570819], dtype=float32),
#   'probabilities': array([0.7742918 , 0.22570819], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.792594], dtype=float32),
#   'logistic': array([0.14275499], dtype=float32),
#   'probabilities': array([0.857245, 0.142755], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5011437], dtype=float32),
#   'logistic': array([0.182255], dtype=float32),
#   'probabilities': array([0.817745, 0.182255], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9980993], dtype=float32),
#   'logistic': array([0.11940259], dtype=float32),
#   'probabilities': array([0.8805974 , 0.11940263], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.49474335], dtype=float32),
#   'logistic': array([0.3787768], dtype=float32),
#   'probabilities': array([0.6212232, 0.3787768], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.3150012], dtype=float32),
#   'logistic': array([0.7883488], dtype=float32),
#   'probabilities': array([0.21165116, 0.78834885], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1972692], dtype=float32),
#   'logistic': array([0.76803863], dtype=float32),
#   'probabilities': array([0.23196137, 0.76803863], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
# ...
#  {'logits': array([0.80981994], dtype=float32),
#   'logistic': array([0.69207114], dtype=float32),
#   'probabilities': array([0.3079289 , 0.69207114], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5097289], dtype=float32),
#   'logistic': array([0.6247429], dtype=float32),
#   'probabilities': array([0.3752571, 0.6247429], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.8475195], dtype=float32),
#   'logistic': array([0.70004654], dtype=float32),
#   'probabilities': array([0.29995346, 0.70004654], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.08956337], dtype=float32),
#   'logistic': array([0.47762412], dtype=float32),
#   'probabilities': array([0.5223759, 0.4776241], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.83162767], dtype=float32),
#   'logistic': array([0.30330104], dtype=float32),
#   'probabilities': array([0.69669896, 0.303301  ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.06113112], dtype=float32),
#   'logistic': array([0.51527804], dtype=float32),
#   'probabilities': array([0.484722  , 0.51527804], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5490103], dtype=float32),
#   'logistic': array([0.17522925], dtype=float32),
#   'probabilities': array([0.82477075, 0.17522927], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8232905], dtype=float32),
#   'logistic': array([0.13903949], dtype=float32),
#   'probabilities': array([0.8609604, 0.1390395], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5285616], dtype=float32),
#   'logistic': array([0.17820424], dtype=float32),
#   'probabilities': array([0.8217957 , 0.17820422], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.05970037], dtype=float32),
#   'logistic': array([0.51492065], dtype=float32),
#   'probabilities': array([0.48507932, 0.51492065], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.7211256], dtype=float32),
#   'logistic': array([0.06173819], dtype=float32),
#   'probabilities': array([0.93826175, 0.06173823], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9458349], dtype=float32),
#   'logistic': array([0.27972323], dtype=float32),
#   'probabilities': array([0.7202767, 0.2797232], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6423237], dtype=float32),
#   'logistic': array([0.16214912], dtype=float32),
#   'probabilities': array([0.83785087, 0.16214912], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.90847826], dtype=float32),
#   'logistic': array([0.28731135], dtype=float32),
#   'probabilities': array([0.7126887 , 0.28731135], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2019966], dtype=float32),
#   'logistic': array([0.23112023], dtype=float32),
#   'probabilities': array([0.7688798 , 0.23112023], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0388497], dtype=float32),
#   'logistic': array([0.26137203], dtype=float32),
#   'probabilities': array([0.738628, 0.261372], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.2241986], dtype=float32),
#   'logistic': array([0.7728015], dtype=float32),
#   'probabilities': array([0.22719844, 0.7728016 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5538416], dtype=float32),
#   'logistic': array([0.17453215], dtype=float32),
#   'probabilities': array([0.8254679 , 0.17453212], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9558752], dtype=float32),
#   'logistic': array([0.12391409], dtype=float32),
#   'probabilities': array([0.8760859 , 0.12391415], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.4451698], dtype=float32),
#   'logistic': array([0.6094902], dtype=float32),
#   'probabilities': array([0.3905098, 0.6094902], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.04150021], dtype=float32),
#   'logistic': array([0.48962644], dtype=float32),
#   'probabilities': array([0.51037353, 0.4896264 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.7423387], dtype=float32),
#   'logistic': array([0.85098386], dtype=float32),
#   'probabilities': array([0.14901613, 0.8509839 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.61585844], dtype=float32),
#   'logistic': array([0.649276], dtype=float32),
#   'probabilities': array([0.35072395, 0.649276  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9536581], dtype=float32),
#   'logistic': array([0.12415503], dtype=float32),
#   'probabilities': array([0.87584496, 0.12415502], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.61610687], dtype=float32),
#   'logistic': array([0.6493326], dtype=float32),
#   'probabilities': array([0.3506674, 0.6493326], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.16348624], dtype=float32),
#   'logistic': array([0.5407808], dtype=float32),
#   'probabilities': array([0.45921925, 0.5407808 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.2297604], dtype=float32),
#   'logistic': array([0.77377665], dtype=float32),
#   'probabilities': array([0.22622336, 0.7737766 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.268185], dtype=float32),
#   'logistic': array([0.2195681], dtype=float32),
#   'probabilities': array([0.78043187, 0.2195681 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6136768], dtype=float32),
#   'logistic': array([0.1660788], dtype=float32),
#   'probabilities': array([0.83392125, 0.16607878], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.31029212], dtype=float32),
#   'logistic': array([0.57695657], dtype=float32),
#   'probabilities': array([0.42304346, 0.57695657], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7563524], dtype=float32),
#   'logistic': array([0.14724776], dtype=float32),
#   'probabilities': array([0.8527522 , 0.14724775], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.2710626], dtype=float32),
#   'logistic': array([0.7809246], dtype=float32),
#   'probabilities': array([0.21907541, 0.7809246 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.09970272], dtype=float32),
#   'logistic': array([0.5249051], dtype=float32),
#   'probabilities': array([0.47509497, 0.5249051 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5429541], dtype=float32),
#   'logistic': array([0.17610626], dtype=float32),
#   'probabilities': array([0.8238938 , 0.17610626], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.2695923], dtype=float32),
#   'logistic': array([0.5669928], dtype=float32),
#   'probabilities': array([0.4330072, 0.5669928], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.1020968], dtype=float32),
#   'logistic': array([0.47449794], dtype=float32),
#   'probabilities': array([0.525502 , 0.4744979], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0903573], dtype=float32),
#   'logistic': array([0.1100376], dtype=float32),
#   'probabilities': array([0.88996243, 0.11003758], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.0612092], dtype=float32),
#   'logistic': array([0.51529753], dtype=float32),
#   'probabilities': array([0.4847025 , 0.51529753], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.42970395], dtype=float32),
#   'logistic': array([0.60580295], dtype=float32),
#   'probabilities': array([0.39419702, 0.60580295], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.0215702], dtype=float32),
#   'logistic': array([0.73527837], dtype=float32),
#   'probabilities': array([0.26472163, 0.7352783 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.5115747], dtype=float32),
#   'logistic': array([0.81929445], dtype=float32),
#   'probabilities': array([0.18070553, 0.8192945 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.17482722], dtype=float32),
#   'logistic': array([0.45640418], dtype=float32),
#   'probabilities': array([0.5435958 , 0.45640418], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6857152], dtype=float32),
#   'logistic': array([0.15634017], dtype=float32),
#   'probabilities': array([0.8436599 , 0.15634018], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.3206902], dtype=float32),
#   'logistic': array([0.08942385], dtype=float32),
#   'probabilities': array([0.91057616, 0.08942384], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1088514], dtype=float32),
#   'logistic': array([0.10823948], dtype=float32),
#   'probabilities': array([0.89176047, 0.10823947], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0790471], dtype=float32),
#   'logistic': array([0.2536864], dtype=float32),
#   'probabilities': array([0.7463136 , 0.25368637], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7312497], dtype=float32),
#   'logistic': array([0.32492056], dtype=float32),
#   'probabilities': array([0.67507946, 0.32492056], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0494891], dtype=float32),
#   'logistic': array([0.2593232], dtype=float32),
#   'probabilities': array([0.7406768, 0.2593232], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)}]

# %% [markdown]
# # DNN Classifier

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# W0221 18:23:08.017857 15956 estimator.py:1811] Using temporary folder as model directory: C:\Users\caiyi\AppData\Local\Temp\tmpu4rzqtvb

# %%
# UH OH! AN ERROR. Check out the video to see why and how to fix.
# https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-cea30273f6d4> in <module>
#       1 # UH OH! AN ERROR. Check out the video to see why and how to fix.
#       2 # https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
# ----> 3 dnn_model.train(input_fn=input_func,steps=1000)
#
# ~\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     365
#     366       saving_listeners = _check_listeners_type(saving_listeners)
# --> 367       loss = self._train_model(input_fn, hooks, saving_listeners)
#     368       logging.info('Loss for final step: %s.', loss)
#     369       return self
#
# ~\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1156       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1157     else:
# -> 1158       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1159
#    1160   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# ~\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1186       worker_hooks.extend(input_hooks)
#    1187       estimator_spec = self._call_model_fn(
# -> 1188           features, labels, ModeKeys.TRAIN, self.config)
#    1189       global_step_tensor = training_util.get_global_step(g)
#    1190       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#
# ~\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in _call_model_fn(self, features, labels, mode, config)
#    1144
#    1145     logging.info('Calling model_fn.')
# -> 1146     model_fn_results = self._model_fn(features=features, **kwargs)
#    1147     logging.info('Done calling model_fn.')
#    1148
#
# ~\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\canned\dnn.py in _model_fn(features, labels, mode, config)
#     810           input_layer_partitioner=input_layer_partitioner,
#     811           config=config,
# --> 812           batch_norm=batch_norm)
#     813
#     814     super(DNNClassifier, self).__init__(
#
# ~\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\canned\dnn.py in _dnn_model_fn(features, labels, mode, head, hidden_units, feature_columns, optimizer, activation_fn, dropout, input_layer_partitioner, config, use_tpu, batch_norm)
#     462         input_layer_partitioner=input_layer_partitioner,
#     463         batch_norm=batch_norm)
# --> 464     logits = logit_fn(features=features, mode=mode)
#     465
#     466     return _get_dnn_estimator_spec(use_tpu, head, features, labels, mode,
#
# ~\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\canned\dnn.py in dnn_logit_fn(features, mode)
#     104         input_layer_partitioner,
#     105         batch_norm,
# --> 106         name='dnn')
#     107     return dnn_model(features, mode)
#     108
#
# ~\Anaconda3\lib\site-packages\tensorflow_estimator\python\estimator\canned\dnn.py in __init__(self, units, hidden_units, feature_columns, activation_fn, dropout, input_layer_partitioner, batch_norm, name, **kwargs)
#     182     if feature_column_lib.is_feature_column_v2(feature_columns):
#     183       self._input_layer = feature_column_lib.DenseFeatures(
# --> 184           feature_columns=feature_columns, name='input_layer')
#     185     else:
#     186       self._input_layer = feature_column.InputLayer(
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\feature_column\feature_column_v2.py in __init__(self, feature_columns, trainable, name, **kwargs)
#     436         name=name,
#     437         expected_column_type=DenseColumn,
# --> 438         **kwargs)
#     439
#     440   @property
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\feature_column\feature_column_v2.py in __init__(self, feature_columns, expected_column_type, trainable, name, **kwargs)
#     336             'You can wrap a categorical column with an '
#     337             'embedding_column or indicator_column. Given: {}'.format(
# --> 338                 expected_column_type, column))
#     339
#     340   def build(self, _):
#
# ValueError: Items of feature_columns must be a <class 'tensorflow.python.feature_column.feature_column_v2.DenseColumn'>. You can wrap a categorical column with an embedding_column or indicator_column. Given: VocabularyListCategoricalColumn(key='Group', vocabulary_list=('A', 'B', 'C', 'D'), dtype=tf.string, default_value=-1, num_oov_buckets=0)

# %%
embedded_group_column = tf.feature_column.embedding_column(assigned_group, dimension=4)

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,embedded_group_column, age_buckets]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,20,20,20,10],feature_columns=feat_cols,n_classes=2)
# Out:
# W0221 18:23:40.393854 15956 estimator.py:1811] Using temporary folder as model directory: C:\Users\caiyi\AppData\Local\Temp\tmpgs55v1p8

# %%
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# W0221 18:23:40.814691 15956 deprecation.py:506] From C:\Users\caiyi\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0221 18:23:41.000233 15956 deprecation.py:323] From C:\Users\caiyi\Anaconda3\lib\site-packages\tensorflow\python\feature_column\feature_column_v2.py:3038: VocabularyListCategoricalColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# W0221 18:23:41.919760 15956 deprecation.py:506] From C:\Users\caiyi\Anaconda3\lib\site-packages\tensorflow\python\training\adagrad.py:76: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)
# Out:
# W0221 18:23:48.587383 15956 metrics_impl.py:804] Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# W0221 18:23:48.605336 15956 metrics_impl.py:804] Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# {'accuracy': 0.71259844,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.8071099,
#  'auc_precision_recall': 0.6774546,
#  'average_loss': 0.5444516,
#  'label/mean': 0.34251967,
#  'loss': 5.3188734,
#  'precision': 0.5648148,
#  'prediction/mean': 0.40845114,
#  'recall': 0.7011494,
#  'global_step': 1000}

# %% [markdown]
# # Great Job!
